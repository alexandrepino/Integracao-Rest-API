# %% [markdown]
# # Importando Bibliotecas utilizadas no projeto

# %%
from googleapiclient.discovery import build
import pandas as pd
from datetime import datetime

# %%
#  Chave gerada no google APIs
youTubeApiKey="AIzaSyDjwyuaSZiFhFH4STE_7sBpgsyvGudXzNI"
# Integração do google APIs com o Python
youtube = build('youtube','v3', developerKey=youTubeApiKey)
# Playlist do youtube que iremos utilizar
playlistId = 'PLpdAy0tYrnKx9CtTmgSdzHz9YQ-C5ZNI9' #Dicas de Pandas Playlist
playlistName = 'Análise de Dados'
nextPage_token = None

# %%
playlist_videos = []

while True:
    res = youtube.playlistItems().list(part='snippet', playlistId = playlistId, maxResults=50, pageToken=nextPage_token).execute()
    playlist_videos += res['items']
  
    nextPage_token = res.get('nestPageToken')

    if nextPage_token is None:
        break

# %%
playlist_videos
# Out:
# [{'kind': 'youtube#playlistItem',
#   'etag': 'asuIYmZe1Lcp1WumxDhBV6-ng0A',
#   'id': 'UExwZEF5MHRZcm5LeDlDdFRtZ1Nkekh6OVlRLUM1Wk5JOS41NkI0NEY2RDEwNTU3Q0M2',
#   'snippet': {'publishedAt': '2021-07-09T21:19:48Z',
#    'channelId': 'UCafFexaRoRylOKdzGBU6Pgg',
#    'title': 'Introdução a Análise de Dados com Python - [Primeiros Passos]',
#    'description': 'Quer saber mais sobre o nosso Curso Completo de Python? Clique no link abaixo para garantir sua vaga na próxima turma:\nhttps://pages.hashtagtreinamentos.com/esperapythonimpressionador?origemurl=hashtag_yt_org_listaesperapython_kCMaqla6Grs\n\nPARA BAIXAR O MINICURSO GRATUITO DE ANÁLISE DE DADOS: http://pages.hashtagtreinamentos.com/inscricao-minicurso-analisededados-python?origemurl=hashtag_yt_org_minipython_kCMaqla6Grs\n\nAqui nos vídeos do canal da Hashtag Programação ensinamos diversas dicas de Python para que você consiga se desenvolver nessa linguagem de programação!\n\n-----------------------------------------------------------------------\n\n► Arquivos Utilizados no Vídeo: https://pages.hashtagtreinamentos.com/arquivo-python-1rquhahty3jo3upp8dddltzzy1c8918nf?origemurl=hashtag_yt_org_planilhapyt_kCMaqla6Grs\n\n► Vídeo de Instalação do Jupyter: https://youtu.be/_eK0z5QbpKA\n\n► Vídeo de Principais Métodos de Pandas: https://youtu.be/C0aj3FjN5e0\n\n-----------------------------------------------------------------------\n\nCaso prefira o vídeo em formato de texto: https://www.hashtagtreinamentos.com/introducao-analise-de-dados-python\n\n-----------------------------------------------------------------------\n\nHashtag Programação\n\n► Inscreva-se em nosso canal: http://bit.ly/3c0LJQi\n► Ative as notificações (clica no sininho)!\n► Curta o nosso vídeo!\n\n-----------------------------------------------------------------------\n\nRedes Sociais\n\n► Blog: https://bit.ly/2MRUZs0\n► YouTube: http://bit.ly/3c0LJQi\n► Instagram: https://bit.ly/3o6dw42\n► Facebook: http://bit.ly/3qGtaF2\n\n-----------------------------------------------------------------------\n\nFala Galera! Nessa aula vamos te mostrar uma introdução análise de dados com Python. Vamos te mostrar um projeto análise de dados!\n\nPara essa aula vamos utilizar o Jupyter, pois ele acaba sendo melhor para a análise de dados no Python, então o objetivo é resolver um desafio (projeto de análise de dados) para te mostrar o passo a passo da análise.\n\nO primeiro passo será importar base de dados para o Python e para isso vamos utilizar a famosa biblioteca pandas, junto com os métodos do pandas para depois fazer alguns tratamentos e análises.\n\nE aí ficou interessado em como utilizar o Python para análise de dados? Então vamos pra aula para não perder nenhum detalhe!\n\nEssa aula é o que você precisa para começar a análise de dados com Python e pandas!\n\n-----------------------------------------------------------------------\n\n#python #hashtagprogramacao',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kCMaqla6Grs/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/kCMaqla6Grs/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/kCMaqla6Grs/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/kCMaqla6Grs/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/kCMaqla6Grs/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Hashtag Programação',
#    'playlistId': 'PLpdAy0tYrnKx9CtTmgSdzHz9YQ-C5ZNI9',
#    'position': 0,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'kCMaqla6Grs'},
#    'videoOwnerChannelTitle': 'Hashtag Programação',
#    'videoOwnerChannelId': 'UCafFexaRoRylOKdzGBU6Pgg'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'ZbXTgMez249FOYLF_FZJZJAhOlM',
#   'id': 'UExwZEF5MHRZcm5LeDlDdFRtZ1Nkekh6OVlRLUM1Wk5JOS4yODlGNEE0NkRGMEEzMEQy',
#   'snippet': {'publishedAt': '2021-07-19T17:11:06Z',
#    'channelId': 'UCafFexaRoRylOKdzGBU6Pgg',
#    'title': 'Como sair do ZERO em Gráficos no Python [Plotly]',
#    'description': 'Quer saber mais sobre o nosso Curso Completo de Python? Clique no link abaixo para garantir sua vaga na próxima turma:\nhttps://pages.hashtagtreinamentos.com/esperapythonimpressionador?origemurl=hashtag_yt_org_listaesperapython_ebeBxiaYZRQ\n\nPARA BAIXAR O MINICURSO GRATUITO DE PYTHON: http://pages.hashtagtreinamentos.com/inscricao-minicurso-python-automacao-org?origemurl=hashtag_yt_org_minipython_ebeBxiaYZRQ\n\nAqui nos vídeos do canal da Hashtag Programação ensinamos diversas dicas de Python para que você consiga se desenvolver nessa linguagem de programação!\n\n-----------------------------------------------------------------------\n\n► Arquivos Utilizados no Vídeo: https://pages.hashtagtreinamentos.com/arquivo-python-1d6d4z6kcendt5lot3o-sila9on31-dyv?origemurl=hashtag_yt_org_planilhapyt_ebeBxiaYZRQ\n\n► Como sair do Zero em Gráficos Utilizando o Matplotlib: https://youtu.be/FDU-D8ddTU4\n\n► Vídeo de Instalação do Jupyter: https://youtu.be/_eK0z5QbpKA\n\n► Vídeo de Introdução ao pandas no Python: https://youtu.be/C0aj3FjN5e0\n\n-----------------------------------------------------------------------\n\nCaso prefira o vídeo em formato de texto: https://www.hashtagtreinamentos.com/como-criar-graficos-no-python\n\n-----------------------------------------------------------------------\n\nHashtag Programação\n\n► Inscreva-se em nosso canal: http://bit.ly/3c0LJQi\n► Ative as notificações (clica no sininho)!\n► Curta o nosso vídeo!\n\n-----------------------------------------------------------------------\n\nRedes Sociais\n\n► Blog: https://bit.ly/2MRUZs0\n► YouTube: http://bit.ly/3c0LJQi\n► Instagram: https://bit.ly/3o6dw42\n► Facebook: http://bit.ly/3qGtaF2\n\n-----------------------------------------------------------------------\n\nFala Galera! Hoje nós vamos fazer outra aula de como sair do zero em gráficos no Python, mas nessa aula nós vamos utilizar a biblioteca Plotly.\n\nComo você já devem saber o Python não possui uma única biblioteca para gráficos, então como já abordamos a matplotlib agora vamos abordar essa outra biblioteca.\n\nVamos te mostrar como fazer gráficos no Python, como fazer alterações no gráfico (edições, alterar eixo, inserir título, mudar o estilo da linha...).\n\nComo em análise de dados é bem importante a parte gráfica vamos te mostrar como criar gráficos em Python e como você pode fazer as alterações nele para poder deixar da melhor forma possível.\n\nComo estamos falando de análise de dados nós vamos também utilizar a biblioteca pandas (até temos um vídeo bem completo sobre essa biblioteca aqui no canal).\n\nNessa aula vamos até te mostrar como criar um Gráfico de Gantt que é muito útil para controle de projetos!\n\nAgora bora pra aula que tem muito conteúdo maneiro fora que ainda vai aprender um pouco sobre a leitura de documentações para te auxiliar nos processos!\n\n-----------------------------------------------------------------------\n\n#python #hashtagprogramacao',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ebeBxiaYZRQ/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/ebeBxiaYZRQ/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/ebeBxiaYZRQ/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/ebeBxiaYZRQ/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/ebeBxiaYZRQ/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Hashtag Programação',
#    'playlistId': 'PLpdAy0tYrnKx9CtTmgSdzHz9YQ-C5ZNI9',
#    'position': 1,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'ebeBxiaYZRQ'},
#    'videoOwnerChannelTitle': 'Hashtag Programação',
#    'videoOwnerChannelId': 'UCafFexaRoRylOKdzGBU6Pgg'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'MEcvOmN8XKe2ahRKcNlhEmPN0F0',
#   'id': 'UExwZEF5MHRZcm5LeDlDdFRtZ1Nkekh6OVlRLUM1Wk5JOS4wMTcyMDhGQUE4NTIzM0Y5',
#   'snippet': {'publishedAt': '2021-07-22T12:02:26Z',
#    'channelId': 'UCafFexaRoRylOKdzGBU6Pgg',
#    'title': 'Como Pegar Informações Atualizadas a Cada Minuto com Python - [Cotação do Dólar]',
#    'description': 'Quer saber mais sobre o nosso Curso Completo de Python? Clique no link abaixo para garantir sua vaga na próxima turma:\nhttps://pages.hashtagtreinamentos.com/esperapythonimpressionador?origemurl=hashtag_yt_org_listaesperapython_v3RtLIoptm8\n\nPARA BAIXAR O MINICURSO GRATUITO DE PYTHON: http://pages.hashtagtreinamentos.com/inscricao-minicurso-python-automacao-org?origemurl=hashtag_yt_org_minipython_v3RtLIoptm8\n\nPARA BAIXAR O MINICURSO GRATUITO DE ANÁLISE DE DADOS: http://pages.hashtagtreinamentos.com/inscricao-minicurso-analisededados-python?origemurl=hashtag_yt_org_minipython_v3RtLIoptm8\n\nAqui nos vídeos do canal da Hashtag Programação ensinamos diversas dicas de Python para que você consiga se desenvolver nessa linguagem de programação!\n\n-----------------------------------------------------------------------\n\n► Arquivos Utilizados no Vídeo: https://pages.hashtagtreinamentos.com/arquivo-python-1b_ule6twmkg4slsiuinavza2kj77chu_?origemurl=hashtag_yt_org_planilhapyt_v3RtLIoptm8\n\n► Vídeo de Instalação do Jupyter: https://youtu.be/_eK0z5QbpKA\n\n► Vídeo de API com Python: https://youtu.be/eel1OVIdfUw\n\n► Introdução ao Pandas no Python: https://youtu.be/C0aj3FjN5e0\n\n► Vídeo de Como Rodar Código Diariamente, Semanalmente: https://youtu.be/SxEjHAlCqmo\n\n-----------------------------------------------------------------------\n\nCaso prefira o vídeo em formato de texto: https://www.hashtagtreinamentos.com/atualizar-dados-em-intervalo-de-tempo-python\n\n-----------------------------------------------------------------------\n\nHashtag Programação\n\n► Inscreva-se em nosso canal: http://bit.ly/3c0LJQi\n► Ative as notificações (clica no sininho)!\n► Curta o nosso vídeo!\n\n-----------------------------------------------------------------------\n\nRedes Sociais\n\n► Blog: https://bit.ly/2MRUZs0\n► YouTube: http://bit.ly/3c0LJQi\n► Instagram: https://bit.ly/3o6dw42\n► Facebook: http://bit.ly/3qGtaF2\n\n-----------------------------------------------------------------------\n\nFala Galera! NA aula de hoje nós vamos te mostrar como fazer uma atualização por minuto no Python, ou seja, como ter informações atualizadas a cada minuto ou o tempo que quiser!\n\nPara esse exemplo vamos utilizar o Jupyter, mas estamos disponibilizando o arquivo na extensão .py para que possa utilizar em outros editores também!\n\nPara executar esse código vamos precisar da biblioteca pandas, biblioteca requests e a biblioteca time (que já vem instalada).\n\nVamos também utilizar uma API de cotação de moedas que é a awesomeapi, no site deles você pode encontrar toda a documentação que precisa para obter as informações desejadas.\n\nNo nosso caso vamos obter as informações de cotação do euro, cotação do dólar e cotação do bitcoin.\n\nPara finalizar vamos primeiro certificar de que o código está rodando corretamente, em seguida vamos utilizar a estrutura de repetição While para criar um loop infinito caso queira que o código fique rodando a cada minuto, 5 minutos...\n\nCaso você queira que o código rode a cada período, mas que rode um número determinado de vezes vamos utilizar a estrutura de repetição For para garantir que o código será executado somente essa quantidade de vezes.\n\nAgora vamos a aula que o conteúdo está irado e vai te ajudar muito na execução dos seus próximos códigos!\n\n-----------------------------------------------------------------------\n\n#python #hashtagprogramacao',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/v3RtLIoptm8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/v3RtLIoptm8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/v3RtLIoptm8/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/v3RtLIoptm8/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/v3RtLIoptm8/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Hashtag Programação',
#    'playlistId': 'PLpdAy0tYrnKx9CtTmgSdzHz9YQ-C5ZNI9',
#    'position': 2,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'v3RtLIoptm8'},
#    'videoOwnerChannelTitle': 'Hashtag Programação',
#    'videoOwnerChannelId': 'UCafFexaRoRylOKdzGBU6Pgg'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'esuwx3vsBwg-FGNKeCMx503nPBE',
#   'id': 'UExwZEF5MHRZcm5LeDlDdFRtZ1Nkekh6OVlRLUM1Wk5JOS41MjE1MkI0OTQ2QzJGNzNG',
#   'snippet': {'publishedAt': '2021-07-26T17:53:30Z',
#    'channelId': 'UCafFexaRoRylOKdzGBU6Pgg',
#    'title': 'Como sair do ZERO em Gráficos no Python [Seaborn]',
#    'description': 'Quer saber mais sobre o nosso Curso Completo de Python? Clique no link abaixo para garantir sua vaga na próxima turma:\nhttps://pages.hashtagtreinamentos.com/esperapythonimpressionador?origemurl=hashtag_yt_org_listaesperapython_-hlzk4FXlUU\n\nPARA BAIXAR O MINICURSO GRATUITO DE ANÁLISE DE DADOS: http://pages.hashtagtreinamentos.com/inscricao-minicurso-analisededados-python?origemurl=hashtag_yt_org_minipython_-hlzk4FXlUU\n\nAqui nos vídeos do canal da Hashtag Programação ensinamos diversas dicas de Python para que você consiga se desenvolver nessa linguagem de programação!\n\n-----------------------------------------------------------------------\n\n► Arquivos Utilizados no Vídeo: https://pages.hashtagtreinamentos.com/arquivo-python-12bm4svm2hzjo5gicu_lcka10ne6v81rb?origemurl=hashtag_yt_org_planilhapyt_-hlzk4FXlUU\n\n► Vídeo de Instalação do Jupyter: https://youtu.be/_eK0z5QbpKA\n\n► Vídeo de Gráficos utilizando o Matplotlib: https://youtu.be/FDU-D8ddTU4\n\n► Vídeo de Gráficos utilizando o Plotly: https://youtu.be/ebeBxiaYZRQ\n\n► Vídeo de Introdução ao Pandas no Python: https://youtu.be/C0aj3FjN5e0\n\n-----------------------------------------------------------------------\n\nCaso prefira o vídeo em formato de texto: https://www.hashtagtreinamentos.com/graficos-com-seaborn-no-python\n\n-----------------------------------------------------------------------\n\nHashtag Programação\n\n► Inscreva-se em nosso canal: http://bit.ly/3c0LJQi\n► Ative as notificações (clica no sininho)!\n► Curta o nosso vídeo!\n\n-----------------------------------------------------------------------\n\nRedes Sociais\n\n► Blog: https://bit.ly/2MRUZs0\n► YouTube: http://bit.ly/3c0LJQi\n► Instagram: https://bit.ly/3o6dw42\n► Facebook: http://bit.ly/3qGtaF2\n\n-----------------------------------------------------------------------\n\nFala Galera! Nós vamos te mostrar mais uma sobre gráficos no Python, mas nessa aula nós vamos abordar a biblioteca Seaborn.\n\nEssa biblioteca é muito útil caso você queira trabalhar com estatística no Python, com análise de dados, ciência de dados e análises gráficas!\n\nVamos também te mostrar no Jupyter (pacote Anaconda) como fazer a relação dessa biblioteca com a biblioteca Pandas que é também excelente para análise de dados.\n\nJá está curioso para saber o que vamos aprender nessa aula? Então aqui vai uma amostra: gráfico de dispersão no Python, gráfico de linha no Python, histograma no Python e até regressão linear no Python!\n\nE aí, bora aprender tudo isso e muito mais? Então corre pra aula!\n\n-----------------------------------------------------------------------\n\n#python #hashtagprogramacao',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-hlzk4FXlUU/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/-hlzk4FXlUU/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/-hlzk4FXlUU/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/-hlzk4FXlUU/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/-hlzk4FXlUU/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Hashtag Programação',
#    'playlistId': 'PLpdAy0tYrnKx9CtTmgSdzHz9YQ-C5ZNI9',
#    'position': 3,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '-hlzk4FXlUU'},
#    'videoOwnerChannelTitle': 'Hashtag Programação',
#    'videoOwnerChannelId': 'UCafFexaRoRylOKdzGBU6Pgg'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '6fBOHh5l4XEq3ILjbldv8gNd29w',
#   'id': 'UExwZEF5MHRZcm5LeDlDdFRtZ1Nkekh6OVlRLUM1Wk5JOS4wOTA3OTZBNzVEMTUzOTMy',
#   'snippet': {'publishedAt': '2021-07-26T17:54:41Z',
#    'channelId': 'UCafFexaRoRylOKdzGBU6Pgg',
#    'title': 'Como sair do ZERO em Gráficos no Python [Matplotlib]',
#    'description': 'Quer saber mais sobre o nosso Curso Completo de Python? Clique no link abaixo para garantir sua vaga na próxima turma:\nhttps://pages.hashtagtreinamentos.com/esperapythonimpressionador?origemurl=hashtag_yt_org_listaesperapython_FDU-D8ddTU4\n\nPARA BAIXAR O MINICURSO DE INTRODUÇÃO AO PYTHON: http://pages.hashtagtreinamentos.com/inscricao-minicurso-python-automacao-org?origemurl=hashtag_yt_org_minipython_FDU-D8ddTU4\n\nAqui nos vídeos do canal da Hashtag Programação ensinamos diversas dicas de Python para que você consiga se desenvolver nessa linguagem de programação!\n\n-----------------------------------------------------------------------\n\n► Arquivos Utilizados no Vídeo: https://pages.hashtagtreinamentos.com/arquivo-python-1xgdk-iocwsbzbix0wsnxipprh-q-eq-v?origemurl=hashtag_yt_org_planilhapyt_FDU-D8ddTU4\n\n► Vídeo de Instalação do Jupyter: https://youtu.be/_eK0z5QbpKA\n\n► Como Sair do Zero no Python em 1 Aula: https://youtu.be/GQpQha2Mfpg\n\n► Introdução ao Pandas no Python: https://youtu.be/C0aj3FjN5e0 \n\n-----------------------------------------------------------------------\n\nCaso prefira o vídeo em formato de texto: https://www.hashtagtreinamentos.com/saia-do-zero-em-graficos-python\n\n-----------------------------------------------------------------------\n\nHashtag Programação\n\n► Inscreva-se em nosso canal: http://bit.ly/3c0LJQi\n► Ative as notificações (clica no sininho)!\n► Curta o nosso vídeo!\n\n-----------------------------------------------------------------------\n\nRedes Sociais\n\n► Blog: https://bit.ly/2MRUZs0\n► YouTube: http://bit.ly/3c0LJQi\n► Instagram: https://bit.ly/3o6dw42\n► Facebook: http://bit.ly/3qGtaF2\n\n-----------------------------------------------------------------------\n\nFala Galera! Essa é mais uma super aula aqui no canal para te mostrar como Sair do ZERO em Gráficos no Python!\n\nJá temos uma aula completa de Python e da biblioteca pandas, então agora vamos ensinar vocês como criar gráficos no Python e como formatar gráficos no Python!\n\nAssim você já vai poder fazer suas análises e utilizar os gráficos para melhorar suas análises e melhorar os resultados mostrados.\n\nPara a criação dos gráficos nós vamos utilizar a biblioteca matplotlib que é uma das bibliotecas gráficas do Python.\n\nE aí, preparado para aprender tudo o que precisa sobre gráficos para complementar seus conhecimentos em Python? Então bora pra aula!\n\n-----------------------------------------------------------------------\n\n#python #hashtagprogramacao',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FDU-D8ddTU4/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/FDU-D8ddTU4/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/FDU-D8ddTU4/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'Hashtag Programação',
#    'playlistId': 'PLpdAy0tYrnKx9CtTmgSdzHz9YQ-C5ZNI9',
#    'position': 4,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'FDU-D8ddTU4'},
#    'videoOwnerChannelTitle': 'Hashtag Programação',
#    'videoOwnerChannelId': 'UCafFexaRoRylOKdzGBU6Pgg'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '-g3eIlN7E4_fysosupQTZJsicSQ',
#   'id': 'UExwZEF5MHRZcm5LeDlDdFRtZ1Nkekh6OVlRLUM1Wk5JOS4xMkVGQjNCMUM1N0RFNEUx',
#   'snippet': {'publishedAt': '2021-08-26T19:19:35Z',
#    'channelId': 'UCafFexaRoRylOKdzGBU6Pgg',
#    'title': 'Como Integrar Python e SQL - Passo a Passo com Exemplo Prático',
#    'description': 'Quer saber mais sobre o nosso Curso Completo de Python? Clique no link abaixo para garantir sua vaga na próxima turma:\nhttps://pages.hashtagtreinamentos.com/esperapythonimpressionador?origemurl=hashtag_yt_org_listaesperapython_Mdg1D-Kdmrw\n\nPARA BAIXAR O MINICURSO GRATUITO DE SQL:\nhttps://excelparaestagio.klickpages.com.br/inscricao-minicurso-sql?origemurl=hashtag_yt_org_minicursosql_Mdg1D-Kdmrw\n\n-----------------------------------------------------------------------\n\n► Arquivos Utilizados no Vídeo: https://pages.hashtagtreinamentos.com/arquivo-python-13Jv5Z_0LktN1Rg_Ae3Lgo6gzzkdaBom5?origemurl=hashtag_yt_org_planilhapyt_Mdg1D-Kdmrw\n\n► Vídeo de Instalação do PyCharm: https://youtu.be/HNUq8X_0nlM\n\n-----------------------------------------------------------------------\n\nCaso prefira o vídeo em formato de texto: https://www.hashtagtreinamentos.com/integrar-sql-e-python\n\n-----------------------------------------------------------------------\n\nHoje eu vou te mostrar como integrar Python e SQL para você que precisa atualizar o seu banco de dados ou puxar as informações desse banco para fazer suas análises!\n\nPrimeiro eu vou te mostrar como criar banco de dados no SQL para você que não tenha nenhum consiga praticar e entender da mesma forma.\n\nTendo o banco de dados criado nós já podemos partir para a integração entre Python e SQL e vamos fazer isso com a biblioteca pyodbc.\n\nPara escrever o nosso código eu vou utilizar o editor de Python PyCharm (na descrição temos o link de um vídeo explicando o passo a passo do download).\n\nVocê vai ver que integrar SQL com Python o código é bem simples, mas se quiser dar mais comandos ao seu banco de dados é importante que você conheça a linguagem de programação para que consiga dar os comandos de forma correta.\n\nE aí, está curioso para saber como integrar Python com SQL e começar a fazer suas automações e análises de dados puxando diretamente do seu banco de dados?\n\n-----------------------------------------------------------------------\n\nHashtag Programação\n\n► Inscreva-se em nosso canal: http://bit.ly/3c0LJQi\n► Ative as notificações (clica no sininho)!\n► Curta o nosso vídeo!\n\n-----------------------------------------------------------------------\n\nRedes Sociais\n\n► Blog: https://bit.ly/2MRUZs0\n► YouTube: http://bit.ly/3c0LJQi\n► Instagram: https://bit.ly/3o6dw42\n► Facebook: http://bit.ly/3qGtaF2\n\nAqui nos vídeos do canal da Hashtag Programação ensinamos diversas dicas de Python para que você consiga se desenvolver nessa linguagem de programação!\n\n-----------------------------------------------------------------------\n\n#python #hashtagprogramacao',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Mdg1D-Kdmrw/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/Mdg1D-Kdmrw/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/Mdg1D-Kdmrw/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/Mdg1D-Kdmrw/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/Mdg1D-Kdmrw/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Hashtag Programação',
#    'playlistId': 'PLpdAy0tYrnKx9CtTmgSdzHz9YQ-C5ZNI9',
#    'position': 5,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'Mdg1D-Kdmrw'},
#    'videoOwnerChannelTitle': 'Hashtag Programação',
#    'videoOwnerChannelId': 'UCafFexaRoRylOKdzGBU6Pgg'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'g9azvWbFx-7o7ChV0OFq5wuXWYY',
#   'id': 'UExwZEF5MHRZcm5LeDlDdFRtZ1Nkekh6OVlRLUM1Wk5JOS41MzJCQjBCNDIyRkJDN0VD',
#   'snippet': {'publishedAt': '2021-09-13T16:27:44Z',
#    'channelId': 'UCafFexaRoRylOKdzGBU6Pgg',
#    'title': 'Como Usar Pandas no PyCharm [Pandas no Python]',
#    'description': 'Quer saber mais sobre o nosso Curso Completo de Python? Clique no link abaixo para garantir sua vaga na próxima turma:\nhttps://pages.hashtagtreinamentos.com/esperapythonimpressionador?origemurl=hashtag_yt_org_listaesperapython_2_ytBPzqzJ4\n\nPARA BAIXAR O MINICURSO GRATUITO DE ANÁLISE DE DADOS: http://pages.hashtagtreinamentos.com/inscricao-minicurso-analisededados-python?origemurl=hashtag_yt_org_minipython_2_ytBPzqzJ4\n\n-----------------------------------------------------------------------\n\n► Arquivos Utilizados no Vídeo: https://pages.hashtagtreinamentos.com/arquivo-python-13iyh_C0_AAczXbtGw4GaxxPG3QWBzFo_?origemurl=hashtag_yt_org_planilhapyt_2_ytBPzqzJ4\n\n► Vídeo de Instalação do Jupyter\nhttps://youtu.be/_eK0z5QbpKA\n\n► Vídeo de Instalação do PyCharm\nhttps://youtu.be/HNUq8X_0nlM\n\n► Introdução ao Pandas no Python - [SAIA DO ZERO EM 1 AULA]\nhttps://youtu.be/C0aj3FjN5e0\n\n-----------------------------------------------------------------------\n\nCaso prefira o vídeo em formato de texto: https://www.hashtagtreinamentos.com/pandas-no-pycharm-python\n\n-----------------------------------------------------------------------\n\nVocê já deve ter ouvido falar em Pandas no Python não é mesmo? Mas você sabia que é possível utilizá-lo no PyCharm também?\n\nO mais comum é você visualizar a utilização do Pandas no Jupyter para análise de dados no Python, no entanto, hoje eu vou te mostrar como usar pandas no Pycharm.\n\nAssim mesmo que você não tenha o Jupyter instalado no seu computador vai poder fazer sua análise de dados com pandas normalmente.\n\nO pandas é uma biblioteca para análise de dados muito utilizada no Python, então vai te ajudar muito para fazer essas análises.\n\nOutro ponto interessante é que vou te mostrar como criar ambiente virtual no Python para fazermos alguns testes e já utilizar a biblioteca pandas!\n\nVamos ler arquivo em Excel e ler arquivo em csv para que você possa entender como funciona e como vai visualizar esses resultados no Python!\n\n-----------------------------------------------------------------------\n\nHashtag Programação\n\n► Inscreva-se em nosso canal: http://bit.ly/3c0LJQi\n► Ative as notificações (clica no sininho)!\n► Curta o nosso vídeo!\n\n-----------------------------------------------------------------------\n\nRedes Sociais\n\n► Blog: https://bit.ly/2MRUZs0\n► YouTube: http://bit.ly/3c0LJQi\n► Instagram: https://bit.ly/3o6dw42\n► Facebook: http://bit.ly/3qGtaF2\n\nAqui nos vídeos do canal da Hashtag Programação ensinamos diversas dicas de Python para que você consiga se desenvolver nessa linguagem de programação!\n\n-----------------------------------------------------------------------\n\n#python #hashtagprogramacao',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2_ytBPzqzJ4/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/2_ytBPzqzJ4/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/2_ytBPzqzJ4/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/2_ytBPzqzJ4/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/2_ytBPzqzJ4/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Hashtag Programação',
#    'playlistId': 'PLpdAy0tYrnKx9CtTmgSdzHz9YQ-C5ZNI9',
#    'position': 6,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '2_ytBPzqzJ4'},
#    'videoOwnerChannelTitle': 'Hashtag Programação',
#    'videoOwnerChannelId': 'UCafFexaRoRylOKdzGBU6Pgg'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': '_S7O3BHbvXB4H7NpyPgw3t7vxvo',
#   'id': 'UExwZEF5MHRZcm5LeDlDdFRtZ1Nkekh6OVlRLUM1Wk5JOS5DQUNERDQ2NkIzRUQxNTY1',
#   'snippet': {'publishedAt': '2021-09-20T14:27:42Z',
#    'channelId': 'UCafFexaRoRylOKdzGBU6Pgg',
#    'title': 'Webscraping de 1000 Páginas Automaticamente no Python',
#    'description': 'Quer saber mais sobre o nosso Curso Completo de Python? Clique no link abaixo para garantir sua vaga na próxima turma:\nhttps://pages.hashtagtreinamentos.com/esperapythonimpressionador?origemurl=hashtag_yt_org_listaesperapython_kM9eyM7a9L8\n\nPARA BAIXAR O MINICURSO GRATUITO DE PYTHON: http://pages.hashtagtreinamentos.com/inscricao-minicurso-python-automacao-org?origemurl=hashtag_yt_org_minipython_kM9eyM7a9L8\n\n-----------------------------------------------------------------------\n\n► Arquivos Utilizados no Vídeo: https://pages.hashtagtreinamentos.com/arquivo-python-15AzYseU4oFqGCTu18a0aSVsnY3o8H7q0?origemurl=hashtag_yt_org_planilhapyt_kM9eyM7a9L8\n\n► Vídeo de Instalação do PyCharm: https://youtu.be/HNUq8X_0nlM\n\n► Saia do zero em Webscraping no Python com Scrapy\nhttps://youtu.be/QdLgNr1mKQU\n\n► Biblioteca Requests no Python [Métodos GET, POST, PATCH e DELETE]\nhttps://youtu.be/IdviYZIQLlA\n\n-----------------------------------------------------------------------\n\nCaso prefira o vídeo em formato de texto: https://www.hashtagtreinamentos.com/webscraping-de-1000-paginas-no-python\n\n-----------------------------------------------------------------------\n\nVocê provavelmente já ouvir falar de Webscraping Python não é mesmo? Nós já até temos um vídeo aqui no canal, mas hoje vamos te mostrar como fazer webscraping no Python em mais de 1000 páginas de um site.\n\nÉ isso mesmo, vamos utilizar o webscraping automático no Python para buscar dados da web com Python em mais de 1000 páginas.\n\nDessa forma você vai poder pegar dados da web com Python não de uma única página, mas de todas as que precisar dentro de um site para fazer sua análise de dados.\n\nPode ser para busca de preços, empresas, produtos, qualquer informação que você precisar. Então além de conseguir puxar todas as informações de uma página poderá replicar esse procedimento para todas as páginas que precisar!\n\nPara esse procedimento nós vamos utilizar a biblioteca scrapy que também temos vídeos sobre o assunto!\n\nVocê vai notar que ao aprender como buscar dados da web com Python isso vai te ajudar muito no mercado de trabalho.\n\nPois imagine que você tenha que fazer uma busca diária ou semanal de algumas informações em sites dessa maneira.\n\nJá imaginou quanto tempo você iria perder pra fazer isso de forma manual? Esse código na aula rodou em cerca de 10 min! Só 10 min para percorrer todas as informações de mais de 1000 páginas.\n\n-----------------------------------------------------------------------\n\nHashtag Programação\n\n► Inscreva-se em nosso canal: http://bit.ly/3c0LJQi\n► Ative as notificações (clica no sininho)!\n► Curta o nosso vídeo!\n\n-----------------------------------------------------------------------\n\nRedes Sociais\n\n► Blog: https://bit.ly/2MRUZs0\n► YouTube: http://bit.ly/3c0LJQi\n► Instagram: https://bit.ly/3o6dw42\n► Facebook: http://bit.ly/3qGtaF2\n\nAqui nos vídeos do canal da Hashtag Programação ensinamos diversas dicas de Python para que você consiga se desenvolver nessa linguagem de programação!\n\n-----------------------------------------------------------------------\n\n#python #hashtagprogramacao',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/kM9eyM7a9L8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/kM9eyM7a9L8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/kM9eyM7a9L8/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/kM9eyM7a9L8/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/kM9eyM7a9L8/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Hashtag Programação',
#    'playlistId': 'PLpdAy0tYrnKx9CtTmgSdzHz9YQ-C5ZNI9',
#    'position': 7,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'kM9eyM7a9L8'},
#    'videoOwnerChannelTitle': 'Hashtag Programação',
#    'videoOwnerChannelId': 'UCafFexaRoRylOKdzGBU6Pgg'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'Uhg5M92ja5-JMDRrnOasuozXsY4',
#   'id': 'UExwZEF5MHRZcm5LeDlDdFRtZ1Nkekh6OVlRLUM1Wk5JOS45NDk1REZENzhEMzU5MDQz',
#   'snippet': {'publishedAt': '2021-09-24T15:06:17Z',
#    'channelId': 'UCafFexaRoRylOKdzGBU6Pgg',
#    'title': 'Como Ler Textos Dentro de Imagens com Python [Introdução ao OpenCV e Tesseract]',
#    'description': 'Quer saber mais sobre o nosso Curso Completo de Python? Clique no link abaixo para garantir sua vaga na próxima turma:\nhttps://pages.hashtagtreinamentos.com/esperapythonimpressionador?origemurl=hashtag_yt_org_listaesperapython_Wx3SyNwZtsA\n\nPARA BAIXAR O MINICURSO GRATUITO DE ANÁLISE DE DADOS: http://pages.hashtagtreinamentos.com/inscricao-minicurso-analisededados-python?origemurl=hashtag_yt_org_minipython_Wx3SyNwZtsA\n\n-----------------------------------------------------------------------\n\n► Arquivos Utilizados no Vídeo: https://pages.hashtagtreinamentos.com/arquivo-python-1hkddnn-XeQlc1gXeI1KfJc39SSiS2LH_?origemurl=hashtag_yt_org_planilhapyt_Wx3SyNwZtsA\n\n-----------------------------------------------------------------------\n\nCaso prefira o vídeo em formato de texto: https://www.hashtagtreinamentos.com/ler-textos-dentro-de-imagens-com-python\n\n-----------------------------------------------------------------------\n\nNessa aula eu quero te ensinar algo incrível, que é como ler textos dentro de imagens com Python.\n\nEntão eu vou te mostrar como você vai fazer para poder ler textos que estão dentro de algumas imagens utilizando o Python.\n\nIsso é possível com uma análise de imagens e para fazer esse procedimento eu vou aproveitar e dar uma breve introdução ao OpenCV Python.\n\nAlém da biblioteca OpenCV no Python eu vou te mostrar também um pouco sobre a biblioteca Tesseract no Python.\n\nVocê já imaginou a facilidade que seria você automatizar um processo para identificar esses textos dentro de imagens?\n\nPois normalmente você não consegue obter ou simplesmente copiar por se tratar de uma imagem! Agora pensa no quanto isso iria facilitar o seu trabalho de pegar os textos de dentro das imagens?\n\nVocê conseguiria automatizar esse processo e ainda ser muito mais produtivo na sua empresa!\n\n-----------------------------------------------------------------------\n\nHashtag Programação\n\n► Inscreva-se em nosso canal: http://bit.ly/3c0LJQi\n► Ative as notificações (clica no sininho)!\n► Curta o nosso vídeo!\n\n-----------------------------------------------------------------------\n\nRedes Sociais\n\n► Blog: https://bit.ly/2MRUZs0\n► YouTube: http://bit.ly/3c0LJQi\n► Instagram: https://bit.ly/3o6dw42\n► Facebook: http://bit.ly/3qGtaF2\n\nAqui nos vídeos do canal da Hashtag Programação ensinamos diversas dicas de Python para que você consiga se desenvolver nessa linguagem de programação!\n\n-----------------------------------------------------------------------\n\n#python #hashtagprogramacao',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Wx3SyNwZtsA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/Wx3SyNwZtsA/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/Wx3SyNwZtsA/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/Wx3SyNwZtsA/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/Wx3SyNwZtsA/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Hashtag Programação',
#    'playlistId': 'PLpdAy0tYrnKx9CtTmgSdzHz9YQ-C5ZNI9',
#    'position': 8,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'Wx3SyNwZtsA'},
#    'videoOwnerChannelTitle': 'Hashtag Programação',
#    'videoOwnerChannelId': 'UCafFexaRoRylOKdzGBU6Pgg'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'h0OfdNG7acVZUk6cjUjOjKArIdA',
#   'id': 'UExwZEF5MHRZcm5LeDlDdFRtZ1Nkekh6OVlRLUM1Wk5JOS5GNjNDRDREMDQxOThCMDQ2',
#   'snippet': {'publishedAt': '2021-10-28T19:54:37Z',
#    'channelId': 'UCafFexaRoRylOKdzGBU6Pgg',
#    'title': 'Como Trabalhar com Arquivos CSV no Python',
#    'description': 'Quer saber mais sobre o nosso Curso Completo de Python? Clique no link abaixo para garantir sua vaga na próxima turma:\nhttps://pages.hashtagtreinamentos.com/esperapythonimpressionador?origemurl=hashtag_yt_org_listaesperapython_AnJPtKLtc7o\n\nPARA BAIXAR O MINICURSO GRATUITO DE ANÁLISE DE DADOS: http://pages.hashtagtreinamentos.com/inscricao-minicurso-analisededados-python?origemurl=hashtag_yt_org_minipython_AnJPtKLtc7o\n\n-----------------------------------------------------------------------\n\n► Arquivos Utilizados no Vídeo: https://pages.hashtagtreinamentos.com/arquivo-python-1h6UhwOBV-IeMUsccW6YLlKVvr4sTm1xK?origemurl=hashtag_yt_org_planilhapyt_AnJPtKLtc7o\n\n► Vídeo de Instalação do Jupyter: https://youtu.be/_eK0z5QbpKA\n\n► Vídeo de Como Abrir e Fechar Arquivos no Python com a Estrutura With: https://youtu.be/ad8toeTUXZs\n\n-----------------------------------------------------------------------\n\nCaso prefira o vídeo em formato de texto: https://www.hashtagtreinamentos.com/como-trabalhar-com-arquivos-csv-no-python\n\n-----------------------------------------------------------------------\n\nNa aula de hoje eu quero te mostrar como trabalhar com arquivos CSV no Python, pois você já deve ter se deparado com esse tipo de arquivo, mas não sabia como prosseguir.\n\nVou te ensinar 2 formas de trabalhar com arquivo CSV, uma utilizando o método interno do Python que é com a estrutura With no Python (já temos até um vídeo no canal explicando como abrir arquivos no Python com essa estrutura).\n\nE a segunda forma é para que você já possa fazer uma análise de dados com a biblioteca pandas (que é uma biblioteca de análise de dados).\n\nCom essa biblioteca você já vai poder ler o arquivo CSV e já fazer os tratamentos necessários para trabalhar com os dados desse arquivo.\n\nE aí, bora aprender essas duas formas de trabalhar com um arquivo CSV no Python?\n\n-----------------------------------------------------------------------\n\nHashtag Programação\n\n► Inscreva-se em nosso canal: http://bit.ly/3c0LJQi\n► Ative as notificações (clica no sininho)!\n► Curta o nosso vídeo!\n\n-----------------------------------------------------------------------\n\nRedes Sociais\n\n► Blog: https://bit.ly/2MRUZs0\n► YouTube: http://bit.ly/3c0LJQi\n► Instagram: https://bit.ly/3o6dw42\n► Facebook: http://bit.ly/3qGtaF2\n\nAqui nos vídeos do canal da Hashtag Programação ensinamos diversas dicas de Python para que você consiga se desenvolver nessa linguagem de programação!\n\n-----------------------------------------------------------------------\n\n#python #hashtagprogramacao',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AnJPtKLtc7o/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/AnJPtKLtc7o/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/AnJPtKLtc7o/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/AnJPtKLtc7o/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/AnJPtKLtc7o/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Hashtag Programação',
#    'playlistId': 'PLpdAy0tYrnKx9CtTmgSdzHz9YQ-C5ZNI9',
#    'position': 9,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'AnJPtKLtc7o'},
#    'videoOwnerChannelTitle': 'Hashtag Programação',
#    'videoOwnerChannelId': 'UCafFexaRoRylOKdzGBU6Pgg'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'pATZaSykn8ju86VQV7JFfp3ZGyw',
#   'id': 'UExwZEF5MHRZcm5LeDlDdFRtZ1Nkekh6OVlRLUM1Wk5JOS40NzZCMERDMjVEN0RFRThB',
#   'snippet': {'publishedAt': '2021-11-11T13:42:44Z',
#    'channelId': 'UCafFexaRoRylOKdzGBU6Pgg',
#    'title': 'Como Tratar Valores Vazios em uma Base de Dados com Python',
#    'description': 'Quer saber mais sobre o nosso Curso Completo de Python? Clique no link abaixo para garantir sua vaga na próxima turma:\nhttps://pages.hashtagtreinamentos.com/esperapythonimpressionador?origemurl=hashtag_yt_org_listaesperapython_rVJW-rgJUkY\n\nPARA BAIXAR O MINICURSO GRATUITO DE ANÁLISE DE DADOS: http://pages.hashtagtreinamentos.com/inscricao-minicurso-analisededados-python?origemurl=hashtag_yt_org_minipython_rVJW-rgJUkY\n\n-----------------------------------------------------------------------\n\n► Arquivos Utilizados no Vídeo: https://pages.hashtagtreinamentos.com/arquivo-python-1OkhM_PBHInPU1c8b-v2TZAiQdHIjWu6Q?origemurl=hashtag_yt_org_planilhapyt_rVJW-rgJUkY\n\n► Vídeo de Instalação do Jupyter: https://youtu.be/_eK0z5QbpKA\n\n► Vídeo dos Principais Métodos do Pandas: https://youtu.be/C0aj3FjN5e0\n\n-----------------------------------------------------------------------\n\nCaso prefira o vídeo em formato de texto: https://www.hashtagtreinamentos.com/tratar-valores-vazios-no-python\n\n-----------------------------------------------------------------------\n\nFala Galera! Hoje nós vamos tratar de um assunto muito interessante que é como tratar valores vazios em uma base de dados com Python!\n\nMuitas das vezes dentro da sua base de dados você vai se deparar com valores e precisa saber como tratá-los.\n\nPor isso fizemos essa aula para te mostrar alguns métodos de tratamento e o que você pode fazer com esses dados.\n\nVamos te mostrar alguns exemplos de tratamento dessas informações vazias, pois nem sempre nós vamos tratá-las da mesma maneira.\n\nAté porque tudo vai depender do tipo de dado, como está sendo feita a análise de dados no Python, qual é o seu objetivo com esses dados, se eles podem ser eliminados, se precisamos substituí-los, e assim por diante.\n\nEntão vamos te mostrar alguns exemplos utilizando a biblioteca pandas e a biblioteca numpy para que você saiba como tratar esses valores vazios em cada ocasião!\n\n-----------------------------------------------------------------------\n\nHashtag Programação\n\n► Inscreva-se em nosso canal: http://bit.ly/3c0LJQi\n► Ative as notificações (clica no sininho)!\n► Curta o nosso vídeo!\n\n-----------------------------------------------------------------------\n\nRedes Sociais\n\n► Blog: https://bit.ly/2MRUZs0\n► YouTube: http://bit.ly/3c0LJQi\n► Instagram: https://bit.ly/3o6dw42\n► Facebook: http://bit.ly/3qGtaF2\n\nAqui nos vídeos do canal da Hashtag Programação ensinamos diversas dicas de Python para que você consiga se desenvolver nessa linguagem de programação!\n\n-----------------------------------------------------------------------\n\n#python #hashtagprogramacao',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/rVJW-rgJUkY/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/rVJW-rgJUkY/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/rVJW-rgJUkY/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/rVJW-rgJUkY/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/rVJW-rgJUkY/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Hashtag Programação',
#    'playlistId': 'PLpdAy0tYrnKx9CtTmgSdzHz9YQ-C5ZNI9',
#    'position': 10,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'rVJW-rgJUkY'},
#    'videoOwnerChannelTitle': 'Hashtag Programação',
#    'videoOwnerChannelId': 'UCafFexaRoRylOKdzGBU6Pgg'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'E-0tvrsnhsKUCNusbN_rBKS7Av4',
#   'id': 'UExwZEF5MHRZcm5LeDlDdFRtZ1Nkekh6OVlRLUM1Wk5JOS5EMEEwRUY5M0RDRTU3NDJC',
#   'snippet': {'publishedAt': '2021-11-29T20:24:43Z',
#    'channelId': 'UCafFexaRoRylOKdzGBU6Pgg',
#    'title': 'Interface Gráfica + Banco (SQlite) + Exportação para Excel (Pandas)',
#    'description': 'Quer saber mais sobre o nosso Curso Completo de Python? Clique no link abaixo para garantir sua vaga na próxima turma:\nhttps://pages.hashtagtreinamentos.com/esperapythonimpressionador?origemurl=hashtag_yt_org_listaesperapython_9z4Uz9Y-TZM\n\nPARA BAIXAR O MINICURSO GRATUITO DE PYTHON: http://pages.hashtagtreinamentos.com/inscricao-minicurso-python-automacao-org?origemurl=hashtag_yt_org_minipython_9z4Uz9Y-TZM\n\n-----------------------------------------------------------------------\n\n► Arquivos Utilizados no Vídeo: https://pages.hashtagtreinamentos.com/arquivo-python-1q94yS6J_HuPVgQz3xp9Ns9BEPwe_zjvM?origemurl=hashtag_yt_org_planilhapyt_9z4Uz9Y-TZM\n\n► Vídeo Ferramenta de Cadastro no Python: https://youtu.be/TXlkiMIBlTM\n\n► Vídeo Ferramenta de Cadastro no Python com Pandas - Parte 2: https://youtu.be/Av1fItUacgQ\n\n-----------------------------------------------------------------------\n\nCaso prefira o vídeo em formato de texto: https://www.hashtagtreinamentos.com/cadastro-de-clientes-no-python\n\n-----------------------------------------------------------------------\n\nFala Galera! Hoje eu quero fazer uma nova ferramenta de cadastro no Python utilizando banco de dados SQlite e fazendo uma integração com o Excel.\n\nEntão nós vamos ter uma ferramenta de cadastro que armazena as informações no banco de dados e pode exportar para o Excel essas informações.\n\nA ideia é fazer a integração do Python com banco de dados e fazer a integração do Python com Excel para que possamos passar essas informações do banco para o Excel.\n\nNós vamos utilizar a biblioteca tkinter (para interface gráfica), biblioteca sqlite3 e a biblioteca pandas (que é a biblioteca para análise de dados).\n\nLembrando que vamos criar uma outra ferramenta de cadastro, não será a mesma das outras aulas, então vamos construir uma ferramenta de cadastro de clientes.\n\nVamos te mostrar todo o procedimento para registrar os dados e fazer a exportação para Excel com pandas.\n\n-----------------------------------------------------------------------\n\nHashtag Programação\n\n► Inscreva-se em nosso canal: http://bit.ly/3c0LJQi\n► Ative as notificações (clica no sininho)!\n► Curta o nosso vídeo!\n\n-----------------------------------------------------------------------\n\nRedes Sociais\n\n► Blog: https://bit.ly/2MRUZs0\n► YouTube: http://bit.ly/3c0LJQi\n► Instagram: https://bit.ly/3o6dw42\n► Facebook: http://bit.ly/3qGtaF2\n\nAqui nos vídeos do canal da Hashtag Programação ensinamos diversas dicas de Python para que você consiga se desenvolver nessa linguagem de programação!\n\n-----------------------------------------------------------------------\n\n#python #hashtagprogramacao',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9z4Uz9Y-TZM/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/9z4Uz9Y-TZM/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/9z4Uz9Y-TZM/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/9z4Uz9Y-TZM/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/9z4Uz9Y-TZM/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Hashtag Programação',
#    'playlistId': 'PLpdAy0tYrnKx9CtTmgSdzHz9YQ-C5ZNI9',
#    'position': 11,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '9z4Uz9Y-TZM'},
#    'videoOwnerChannelTitle': 'Hashtag Programação',
#    'videoOwnerChannelId': 'UCafFexaRoRylOKdzGBU6Pgg'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'V6eiaE2ZC2m-MAByGIE6-Zx2ESY',
#   'id': 'UExwZEF5MHRZcm5LeDlDdFRtZ1Nkekh6OVlRLUM1Wk5JOS45ODRDNTg0QjA4NkFBNkQy',
#   'snippet': {'publishedAt': '2021-12-02T13:55:01Z',
#    'channelId': 'UCafFexaRoRylOKdzGBU6Pgg',
#    'title': 'Trade de Criptomoedas com Python - API da Binance',
# ...
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/QkDiBWJ8Row/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/QkDiBWJ8Row/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Hashtag Programação',
#    'playlistId': 'PLpdAy0tYrnKx9CtTmgSdzHz9YQ-C5ZNI9',
#    'position': 25,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'QkDiBWJ8Row'},
#    'videoOwnerChannelTitle': 'Hashtag Programação',
#    'videoOwnerChannelId': 'UCafFexaRoRylOKdzGBU6Pgg'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'YTeT2CdN00JcqnP-ocJficdgtoA',
#   'id': 'UExwZEF5MHRZcm5LeDlDdFRtZ1Nkekh6OVlRLUM1Wk5JOS5DQ0MyQ0Y4Mzg0M0VGOEYw',
#   'snippet': {'publishedAt': '2022-03-21T11:43:37Z',
#    'channelId': 'UCafFexaRoRylOKdzGBU6Pgg',
#    'title': 'Estatística para Data Science no Python - Por Que Estudar Estatística?',
#    'description': 'Quer saber mais sobre o nosso Curso Completo de Python? Clique no link abaixo para garantir sua vaga na próxima turma:\nhttps://pages.hashtagtreinamentos.com/esperapythonimpressionador?origemurl=hashtag_yt_org_listaesperapython_lm5MK7SAbs0\n\nPARA BAIXAR O MINICURSO GRATUITO DE ANÁLISE DE DADOS: http://pages.hashtagtreinamentos.com/inscricao-minicurso-analisededados-python?origemurl=hashtag_yt_org_minipython_lm5MK7SAbs0\n\n-----------------------------------------------------------------------\n\n► Arquivos Utilizados no Vídeo: https://pages.hashtagtreinamentos.com/arquivo-python-1m9fn-vo0bO4irlKH7MOfVgg-HYI4sYG2?origemurl=hashtag_yt_org_planilhapyt_lm5MK7SAbs0\n\n► Primeiros Passos em Ciência de Dados no Python: https://youtu.be/PGR3RfTSnWU\n\n► Introdução ao Pandas no Python - [SAIA DO ZERO EM 1 AULA]: https://youtu.be/C0aj3FjN5e0\n\n-----------------------------------------------------------------------\n\nCaso prefira o vídeo em formato de texto: https://www.hashtagtreinamentos.com/estatistica-para-data-science-no-python\n\n-----------------------------------------------------------------------\n\nFala Impressionadores! Hoje nós vamos abordar o tema de estatística pada data Science no Python.\n\nEsse é um tema muito importante, pois além de entender os conceitos estatísticos você precisa saber como avaliar as informações que recebe para não fazer escolhas/análises erradas.\n\nNessa aula eu vou te mostrar por que estudar estatística e vou te mostrar o que é média, o que é mediana e o que é moda para que você saiba diferenciar essas informações para poder fazer suas análises.\n\nOutro ponto muito importante é entender esses conceitos para que você simplesmente não tome uma decisão baseado apenas em uma dessas informações.\n\nPara te mostrar esses exemplos vamos utilizar a biblioteca pandas no Python que é uma biblioteca para análise de dados!\n\nE aí, bora aprender estatística em ciência de dados?\n\n-----------------------------------------------------------------------\n\nHashtag Programação\n\n► Inscreva-se em nosso canal: http://bit.ly/3c0LJQi\n► Ative as notificações (clica no sininho)!\n► Curta o nosso vídeo!\n\n-----------------------------------------------------------------------\n\nRedes Sociais\n\n► Blog: https://bit.ly/2MRUZs0\n► YouTube: http://bit.ly/3c0LJQi\n► Instagram: https://bit.ly/3o6dw42\n► Facebook: http://bit.ly/3qGtaF2\n\nAqui nos vídeos do canal da Hashtag Programação ensinamos diversas dicas de Python para que você consiga se desenvolver nessa linguagem de programação!\n\n-----------------------------------------------------------------------\n\n#python #hashtagprogramacao',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lm5MK7SAbs0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/lm5MK7SAbs0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/lm5MK7SAbs0/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/lm5MK7SAbs0/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/lm5MK7SAbs0/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Hashtag Programação',
#    'playlistId': 'PLpdAy0tYrnKx9CtTmgSdzHz9YQ-C5ZNI9',
#    'position': 26,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'lm5MK7SAbs0'},
#    'videoOwnerChannelTitle': 'Hashtag Programação',
#    'videoOwnerChannelId': 'UCafFexaRoRylOKdzGBU6Pgg'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'A36YlGXCk24jZtngxMlk9QOUBmQ',
#   'id': 'UExwZEF5MHRZcm5LeDlDdFRtZ1Nkekh6OVlRLUM1Wk5JOS4yQUE2Q0JEMTk4NTM3RTZC',
#   'snippet': {'publishedAt': '2022-03-25T18:15:25Z',
#    'channelId': 'UCafFexaRoRylOKdzGBU6Pgg',
#    'title': 'Contas em Python Não Estão Certas? Números com Muitas Casas Decimais',
#    'description': 'Quer saber mais sobre o nosso Curso Completo de Python? Clique no link abaixo para garantir sua vaga na próxima turma:\nhttps://pages.hashtagtreinamentos.com/esperapythonimpressionador?origemurl=hashtag_yt_org_listaesperapython_CH37p_qPwIw\n\nPARA BAIXAR O MINICURSO GRATUITO DE ANÁLISE DE DADOS: http://pages.hashtagtreinamentos.com/inscricao-minicurso-analisededados-python?origemurl=hashtag_yt_org_minipython_CH37p_qPwIw\n\n-----------------------------------------------------------------------\n\nFala Impressionadores! Hoje eu quero falar sobre um assunto bem interessante, que é “Contas em Python não estão certas?”.\n\nVou te mostrar alguns exemplos onde temos contas erradas no Python, mas não porque ele não consegue fazer os cálculos, mas pela maneira que esses cálculos são feitos.\n\nVocê vai notar que em alguns casos temos números com muitas casas decimais como resultado de 2 números com 1 ou duas casas apenas.\n\nPor que isso acontece então? Acontece, pois temos números binários em Python, ou seja, ele pega esse número que você atribuiu a uma variável ou fez seus cálculos e armazena em números binários (combinação de 0 e 1).\n\nEntão ao fazer seu cálculo temos muitas casas decimais no Python, pois o valor não chega a ser exatamente o que você quer.\n\nPor mais que você saiba que as contas em Python estão certas, é necessário em alguns casos retornar o valor exato, então você não vai querer ter que arredondar ou tratar essa informação, não é mesmo?\n\nPara isso podemos utilizar a biblioteca decimal, que serve para armazenar números em formato de texto, o que faz com que o seu resultado seja exatamente o que você está esperando!\n\n-----------------------------------------------------------------------\n\nHashtag Programação\n\n► Inscreva-se em nosso canal: http://bit.ly/3c0LJQi\n► Ative as notificações (clica no sininho)!\n► Curta o nosso vídeo!\n\n-----------------------------------------------------------------------\n\nRedes Sociais\n\n► Blog: https://bit.ly/2MRUZs0\n► YouTube: http://bit.ly/3c0LJQi\n► Instagram: https://bit.ly/3o6dw42\n► Facebook: http://bit.ly/3qGtaF2\n\nAqui nos vídeos do canal da Hashtag Programação ensinamos diversas dicas de Python para que você consiga se desenvolver nessa linguagem de programação!\n\n-----------------------------------------------------------------------\n\n#python #hashtagprogramacao',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/CH37p_qPwIw/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/CH37p_qPwIw/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/CH37p_qPwIw/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/CH37p_qPwIw/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/CH37p_qPwIw/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Hashtag Programação',
#    'playlistId': 'PLpdAy0tYrnKx9CtTmgSdzHz9YQ-C5ZNI9',
#    'position': 27,
#    'resourceId': {'kind': 'youtube#video', 'videoId': 'CH37p_qPwIw'},
#    'videoOwnerChannelTitle': 'Hashtag Programação',
#    'videoOwnerChannelId': 'UCafFexaRoRylOKdzGBU6Pgg'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'T95HH9gVlqshTeVYcVAfEpWSHD4',
#   'id': 'UExwZEF5MHRZcm5LeDlDdFRtZ1Nkekh6OVlRLUM1Wk5JOS5DMkU4NTY1QUFGQTYwMDE3',
#   'snippet': {'publishedAt': '2022-03-28T00:11:28Z',
#    'channelId': 'UCafFexaRoRylOKdzGBU6Pgg',
#    'title': 'Análise Exploratória IMPRESSIONADORA em Python',
#    'description': 'Quer saber mais sobre o nosso Curso Completo de Python? Clique no link abaixo para garantir sua vaga na próxima turma:\nhttps://pages.hashtagtreinamentos.com/esperapythonimpressionador?origemurl=hashtag_yt_org_listaesperapython_4sxhE3wP3Ug\n\nPARA BAIXAR O MINICURSO GRATUITO DE ANÁLISE DE DADOS: http://pages.hashtagtreinamentos.com/inscricao-minicurso-analisededados-python?origemurl=hashtag_yt_org_minipython_4sxhE3wP3Ug\n\n-----------------------------------------------------------------------\n\n► Arquivos Utilizados no Vídeo: https://pages.hashtagtreinamentos.com/arquivo-python-1FztTmDa53lTIDEQp0qRxQDMlY-Tkyvtl?origemurl=hashtag_yt_org_planilhapyt_4sxhE3wP3Ug\n\n► Introdução ao Pandas no Python: https://www.youtube.com/watch?v=C0aj3FjN5e0\n\n► Primeiros Passos em Ciência de Dados no Python: https://www.youtube.com/watch?v=PGR3RfTSnWU&t=4s\n\n► Estatística para Data Science no Python: https://www.youtube.com/watch?v=lm5MK7SAbs0\n\n-----------------------------------------------------------------------\n\nCaso prefira o vídeo em formato de texto: https://www.hashtagtreinamentos.com/analise-exploratoria-em-python\n\n-----------------------------------------------------------------------\n\nFala Impressionadores! Hoje nós vamos falar sobre análise exploratória impressionadora em Python!\n\nVou te mostra os processos que vamos utilizar para fazer essa análise exploratória dos dados que é um passo muito importante no projeto de ciência de dados.\n\nPara fazer essas análises nós vamos utilizar a biblioteca pandas (biblioteca de análise de dados), a biblioteca datetime e alguns gráficos no Python (boxplot) para facilitar o entendimento dos dados.\n\nVamos ver alguns comandos da biblioteca pandas para entender a base de dados, pois esse é um passo muito importante.\n\nNão basta apenas ter a base de dados, precisamos saber quais são os dados, como eles estão organizados, se estão todos corretos, fazer uma análise de outliers (comentamos sobre isso na última aula).\n\nEsse passo é muito importante, pois de fato vamos fazer uma análise exploratória no Python para entender tudo sobre esses dados para que possamos iniciar o nosso projeto de ciência de dados.\n\nPois nada adianta escrever diversas linhas de código sem entender o que está acontecendo não é mesmo?\n\nAgora vamos pra aula de data Science que está iradíssima!\n\n-----------------------------------------------------------------------\n\nHashtag Programação\n\n► Inscreva-se em nosso canal: http://bit.ly/3c0LJQi\n► Ative as notificações (clica no sininho)!\n► Curta o nosso vídeo!\n\n-----------------------------------------------------------------------\n\nRedes Sociais\n\n► Blog: https://bit.ly/2MRUZs0\n► YouTube: http://bit.ly/3c0LJQi\n► Instagram: https://bit.ly/3o6dw42\n► Facebook: http://bit.ly/3qGtaF2\n\nAqui nos vídeos do canal da Hashtag Programação ensinamos diversas dicas de Python para que você consiga se desenvolver nessa linguagem de programação!\n\n-----------------------------------------------------------------------\n\n#python #hashtagprogramacao',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4sxhE3wP3Ug/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/4sxhE3wP3Ug/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/4sxhE3wP3Ug/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/4sxhE3wP3Ug/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/4sxhE3wP3Ug/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Hashtag Programação',
#    'playlistId': 'PLpdAy0tYrnKx9CtTmgSdzHz9YQ-C5ZNI9',
#    'position': 28,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '4sxhE3wP3Ug'},
#    'videoOwnerChannelTitle': 'Hashtag Programação',
#    'videoOwnerChannelId': 'UCafFexaRoRylOKdzGBU6Pgg'}},
#  {'kind': 'youtube#playlistItem',
#   'etag': 'WreLjE5w9XJ9vjphGfysL-gawNg',
#   'id': 'UExwZEF5MHRZcm5LeDlDdFRtZ1Nkekh6OVlRLUM1Wk5JOS44Mjc5REFBRUE2MTdFRDU0',
#   'snippet': {'publishedAt': '2022-04-11T13:33:52Z',
#    'channelId': 'UCafFexaRoRylOKdzGBU6Pgg',
#    'title': 'Usando Machine Learning para Estimativa de Vendas no Python',
#    'description': 'Quer saber mais sobre o nosso Curso Completo de Python? Clique no link abaixo para garantir sua vaga na próxima turma:\nhttps://pages.hashtagtreinamentos.com/esperapythonimpressionador?origemurl=hashtag_yt_org_listaesperapython_3qym7vqFybs\n\nPARA BAIXAR O MINICURSO GRATUITO DE ANÁLISE DE DADOS: http://pages.hashtagtreinamentos.com/inscricao-minicurso-analisededados-python?origemurl=hashtag_yt_org_minipython_3qym7vqFybs\n\n-----------------------------------------------------------------------\n\n► Arquivos Utilizados no Vídeo: https://pages.hashtagtreinamentos.com/arquivo-python-1-DkibFoqSSSxn_0eOKyhVKdfg5GjfSIP?origemurl=hashtag_yt_org_planilhapyt_3qym7vqFybs\n\n► Primeiros Passos em Ciência de Dados no Python: https://www.youtube.com/watch?v=PGR3RfTSnWU&t=92s\n\n► Análise Exploratória IMPRESSIONADORA em Python: https://www.youtube.com/watch?v=4sxhE3wP3Ug\n\n-----------------------------------------------------------------------\n\nFala Impressionadores! Hoje eu quero te mostrar como utilizar o machine learning para fazer estimativa de vendas no Python!\n\nEssa aula ainda faz parte das aulas de ciência de dados no Python para que você aprenda o que fazer dentro de um projeto desses.\n\nEntão nessa parte de data Science nós vamos utilizar a biblioteca pandas, biblioteca matplotlib, biblioteca numpy e claro a análise de dados no Python!\n\nAlém para fazer essa estimativa de vendas no Python, vamos utilizar a regressão linear para encontrar qual a melhor maneira para fazer essa estimativa de vendas sem que você tenha que dar muitas voltas.\n\nE aí, bora continuar nosso estudo de ciência de dados para aprender como estimar vendas no Python utilizando o machine learning?\n\n-----------------------------------------------------------------------\n\nHashtag Programação\n\n► Inscreva-se em nosso canal: http://bit.ly/3c0LJQi\n► Ative as notificações (clica no sininho)!\n► Curta o nosso vídeo!\n\n-----------------------------------------------------------------------\n\nRedes Sociais\n\n► Blog: https://bit.ly/2MRUZs0\n► YouTube: http://bit.ly/3c0LJQi\n► Instagram: https://bit.ly/3o6dw42\n► Facebook: http://bit.ly/3qGtaF2\n\nAqui nos vídeos do canal da Hashtag Programação ensinamos diversas dicas de Python para que você consiga se desenvolver nessa linguagem de programação!\n\n-----------------------------------------------------------------------\n\n#python #hashtagprogramacao',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3qym7vqFybs/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/3qym7vqFybs/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/3qym7vqFybs/hqdefault.jpg',
#      'width': 480,
#      'height': 360},
#     'standard': {'url': 'https://i.ytimg.com/vi/3qym7vqFybs/sddefault.jpg',
#      'width': 640,
#      'height': 480},
#     'maxres': {'url': 'https://i.ytimg.com/vi/3qym7vqFybs/maxresdefault.jpg',
#      'width': 1280,
#      'height': 720}},
#    'channelTitle': 'Hashtag Programação',
#    'playlistId': 'PLpdAy0tYrnKx9CtTmgSdzHz9YQ-C5ZNI9',
#    'position': 29,
#    'resourceId': {'kind': 'youtube#video', 'videoId': '3qym7vqFybs'},
#    'videoOwnerChannelTitle': 'Hashtag Programação',
#    'videoOwnerChannelId': 'UCafFexaRoRylOKdzGBU6Pgg'}}]

# %%
print(f'Número total de videos: {len(playlist_videos)}')
# Out:
# Número total de videos: 30

# %%
videos_ids = list(map(lambda x: x['snippet']['resourceId']['videoId'], playlist_videos))
videos_ids
# Out:
# ['kCMaqla6Grs',
#  'ebeBxiaYZRQ',
#  'v3RtLIoptm8',
#  '-hlzk4FXlUU',
#  'FDU-D8ddTU4',
#  'Mdg1D-Kdmrw',
#  '2_ytBPzqzJ4',
#  'kM9eyM7a9L8',
#  'Wx3SyNwZtsA',
#  'AnJPtKLtc7o',
#  'rVJW-rgJUkY',
#  '9z4Uz9Y-TZM',
#  'NxZ_cl8MUEU',
#  'mCcPmlr7y3U',
#  'BMQ3lM-GVu8',
#  'DjNCk0Dgnkc',
#  'vgPPr9dFOZQ',
#  'T5X1wWiBPaE',
#  'dUxpMU9Bw3U',
#  'BVyZmccKDcQ',
#  'xfv29MiZ4BU',
#  'CRIjrfuaey8',
#  'MvjdqHHsnJ8',
#  'aS64PvDqCbU',
#  '_q3j25ACmQ4',
#  'QkDiBWJ8Row',
#  'lm5MK7SAbs0',
#  'CH37p_qPwIw',
#  '4sxhE3wP3Ug',
#  '3qym7vqFybs']

# %%
stats = []

for video_id in videos_ids:
    res = youtube.videos().list(part='statistics', id=video_id).execute()
    stats += res['items']

# %%
stats
# Out:
# [{'kind': 'youtube#video',
#   'etag': 'ifF4vQ2Y4FQ_toDfkYc3yHqlZuo',
#   'id': 'kCMaqla6Grs',
#   'statistics': {'viewCount': '54607',
#    'likeCount': '3686',
#    'favoriteCount': '0',
#    'commentCount': '71'}},
#  {'kind': 'youtube#video',
#   'etag': 'Ledepj96io8pCGvXZQEtUHStYeY',
#   'id': 'ebeBxiaYZRQ',
#   'statistics': {'viewCount': '6858',
#    'likeCount': '687',
#    'favoriteCount': '0',
#    'commentCount': '26'}},
#  {'kind': 'youtube#video',
#   'etag': '3V_kXmXKpoJXCNdZJV-pcrFqvSQ',
#   'id': 'v3RtLIoptm8',
#   'statistics': {'viewCount': '9479',
#    'likeCount': '743',
#    'favoriteCount': '0',
#    'commentCount': '26'}},
#  {'kind': 'youtube#video',
#   'etag': 'lQ9BF-bVX8Mw3Lf_bQZK2D57jLM',
#   'id': '-hlzk4FXlUU',
#   'statistics': {'viewCount': '5443',
#    'likeCount': '393',
#    'favoriteCount': '0',
#    'commentCount': '19'}},
#  {'kind': 'youtube#video',
#   'etag': 'KHwOqcSHJ-6m1vUtdxDiXmyvwL0',
#   'id': 'FDU-D8ddTU4',
#   'statistics': {'viewCount': '9402',
#    'likeCount': '761',
#    'favoriteCount': '0',
#    'commentCount': '31'}},
#  {'kind': 'youtube#video',
#   'etag': 'cKEBcMaag4JUFq0CBFmVoHrvle4',
#   'id': 'Mdg1D-Kdmrw',
#   'statistics': {'viewCount': '36121',
#    'likeCount': '3190',
#    'favoriteCount': '0',
#    'commentCount': '218'}},
#  {'kind': 'youtube#video',
#   'etag': 'lshVCNwKUxKrt5UhfQ1g3pECHBk',
#   'id': '2_ytBPzqzJ4',
#   'statistics': {'viewCount': '7965',
#    'likeCount': '446',
#    'favoriteCount': '0',
#    'commentCount': '18'}},
#  {'kind': 'youtube#video',
#   'etag': 'hH7tV5VyAAPxCUAtA-anCTpEtJ8',
#   'id': 'kM9eyM7a9L8',
#   'statistics': {'viewCount': '8587',
#    'likeCount': '480',
#    'favoriteCount': '0',
#    'commentCount': '28'}},
#  {'kind': 'youtube#video',
#   'etag': 'ANbj2gsbCCnoqnp2CakPMoGMp-A',
#   'id': 'Wx3SyNwZtsA',
#   'statistics': {'viewCount': '12141',
#    'likeCount': '863',
#    'favoriteCount': '0',
#    'commentCount': '49'}},
#  {'kind': 'youtube#video',
#   'etag': 'Ci8xjskiBAAYhlG9JpGUPyVBJ2E',
#   'id': 'AnJPtKLtc7o',
#   'statistics': {'viewCount': '8147',
#    'likeCount': '465',
#    'favoriteCount': '0',
#    'commentCount': '17'}},
#  {'kind': 'youtube#video',
#   'etag': 'b9wQVgCwXzzbfKSNtXF-mmR79ss',
#   'id': 'rVJW-rgJUkY',
#   'statistics': {'viewCount': '3262',
#    'likeCount': '295',
#    'favoriteCount': '0',
#    'commentCount': '22'}},
#  {'kind': 'youtube#video',
#   'etag': 'I5ouXGxV1fpXxUmZCKqlpk-lQyM',
#   'id': '9z4Uz9Y-TZM',
#   'statistics': {'viewCount': '10646',
#    'likeCount': '749',
#    'favoriteCount': '0',
#    'commentCount': '29'}},
#  {'kind': 'youtube#video',
#   'etag': 'r0LttI11smx0euKhQftrBcxewKk',
#   'id': 'NxZ_cl8MUEU',
#   'statistics': {'viewCount': '25714',
#    'likeCount': '1482',
#    'favoriteCount': '0',
#    'commentCount': '66'}},
#  {'kind': 'youtube#video',
#   'etag': 'MGZ-JXorOqfYFlY1tOeBnmPEMUg',
#   'id': 'mCcPmlr7y3U',
#   'statistics': {'viewCount': '11816',
#    'likeCount': '992',
#    'favoriteCount': '0',
#    'commentCount': '30'}},
#  {'kind': 'youtube#video',
#   'etag': 'MvdyoFrBkwQgmxyC4aZ7InpE-WI',
#   'id': 'BMQ3lM-GVu8',
#   'statistics': {'viewCount': '3704',
#    'likeCount': '369',
#    'favoriteCount': '0',
#    'commentCount': '20'}},
#  {'kind': 'youtube#video',
#   'etag': 'DwZxbr5_OKNaraxIOWYHMc3-Q1w',
#   'id': 'DjNCk0Dgnkc',
#   'statistics': {'viewCount': '3241',
#    'likeCount': '295',
#    'favoriteCount': '0',
#    'commentCount': '14'}},
#  {'kind': 'youtube#video',
#   'etag': 'jHoP_q95oLNKRNFjIW-PA0C_n-A',
#   'id': 'vgPPr9dFOZQ',
#   'statistics': {'viewCount': '12561',
#    'likeCount': '1000',
#    'favoriteCount': '0',
#    'commentCount': '63'}},
#  {'kind': 'youtube#video',
#   'etag': 'wvXI3CgIRBmYh7CPgqR3BFi4BCs',
#   'id': 'T5X1wWiBPaE',
#   'statistics': {'viewCount': '4516',
#    'likeCount': '331',
#    'favoriteCount': '0',
#    'commentCount': '28'}},
#  {'kind': 'youtube#video',
#   'etag': 'nldC0gmfCzTDLZ6DwLoBhrx3_kE',
#   'id': 'dUxpMU9Bw3U',
#   'statistics': {'viewCount': '7555',
#    'likeCount': '513',
#    'favoriteCount': '0',
#    'commentCount': '28'}},
#  {'kind': 'youtube#video',
#   'etag': 'iqJ-3MFIYD3P23Dev5dDohHpzQI',
#   'id': 'BVyZmccKDcQ',
#   'statistics': {'viewCount': '3000',
#    'likeCount': '258',
#    'favoriteCount': '0',
#    'commentCount': '14'}},
#  {'kind': 'youtube#video',
#   'etag': 'RbMxFL-Zgp7p95-D3cqeAvJ6y3Y',
#   'id': 'xfv29MiZ4BU',
#   'statistics': {'viewCount': '2584',
#    'likeCount': '216',
#    'favoriteCount': '0',
#    'commentCount': '11'}},
#  {'kind': 'youtube#video',
#   'etag': 'Fi-7k-7SMJCDFRaoVxpICgu28uQ',
#   'id': 'CRIjrfuaey8',
#   'statistics': {'viewCount': '4443',
#    'likeCount': '468',
#    'favoriteCount': '0',
#    'commentCount': '37'}},
#  {'kind': 'youtube#video',
#   'etag': 'VVbA-zfqavT4cBqMKRjMRkr2vBg',
#   'id': 'aS64PvDqCbU',
#   'statistics': {'viewCount': '15369',
#    'likeCount': '1031',
#    'favoriteCount': '0',
#    'commentCount': '33'}},
#  {'kind': 'youtube#video',
#   'etag': 'DVe7zG_x7jW089xXB85_VHHxQnQ',
#   'id': '_q3j25ACmQ4',
#   'statistics': {'viewCount': '9609',
#    'likeCount': '800',
#    'favoriteCount': '0',
#    'commentCount': '45'}},
#  {'kind': 'youtube#video',
#   'etag': '9-rAbulINPTFgW5H3oaR9wVA-V0',
#   'id': 'QkDiBWJ8Row',
#   'statistics': {'viewCount': '4834',
#    'likeCount': '475',
#    'favoriteCount': '0',
#    'commentCount': '21'}},
#  {'kind': 'youtube#video',
#   'etag': 'duzr-Sy6lBdhvfnC4xQBRk2aqjk',
#   'id': 'lm5MK7SAbs0',
#   'statistics': {'viewCount': '4827',
#    'likeCount': '423',
#    'favoriteCount': '0',
#    'commentCount': '16'}},
#  {'kind': 'youtube#video',
#   'etag': 'Q-7jM6n3H1PY2OexkQd8yuIA1GY',
#   'id': 'CH37p_qPwIw',
#   'statistics': {'viewCount': '3529',
#    'likeCount': '369',
#    'favoriteCount': '0',
#    'commentCount': '10'}},
#  {'kind': 'youtube#video',
#   'etag': 'fjz3fyN2goQtmoEbNkte7gGhjTc',
#   'id': '4sxhE3wP3Ug',
#   'statistics': {'viewCount': '5401',
#    'likeCount': '474',
#    'favoriteCount': '0',
#    'commentCount': '20'}},
#  {'kind': 'youtube#video',
#   'etag': 'pSxfw59vAO9mejbw0JrCAW6GYM4',
#   'id': '3qym7vqFybs',
#   'statistics': {'viewCount': '2874',
#    'likeCount': '269',
#    'favoriteCount': '0',
#    'commentCount': '7'}}]

# %%
videos_title = list(map(lambda x: x['snippet']['title'], playlist_videos))
url_thumbnails = list(map(lambda x: x['snippet']['thumbnails'], playlist_videos))
published_date = list(map(lambda x: str(x['snippet']['publishedAt']), playlist_videos)) 
video_description = list(map(lambda x: x['snippet']['description'], playlist_videos))
videoid = list(map(lambda x: x['snippet']['resourceId']['videoId'], playlist_videos))

# %%
liked = list(map(lambda x: int(x['statistics']['likeCount']), stats))
views = list(map(lambda x: int(x['statistics']['viewCount']), stats))
comment = list(map(lambda x: int(x['statistics']['commentCount']), stats))

# %%
extraction_date = [str(datetime.now())]*len(videos_ids)

# %%
dict_dados = {'title':videos_title,
      'video_id':videoid,
      'video_description':video_description,
      'published_date':published_date,
      'extraction_date':extraction_date,
      'likes':liked,
      'views':views,
      'comment':comment,
      'thumbnail': url_thumbnails}

# %%
playlist_df = pd.DataFrame.from_dict(dict_dados, orient='index').transpose()
playlist_df
# Out:
#                                                 title     video_id  \
# 0   Introdução a Análise de Dados com Python - [Pr...  kCMaqla6Grs
# 1    Como sair do ZERO em Gráficos no Python [Plotly]  ebeBxiaYZRQ
# 2   Como Pegar Informações Atualizadas a Cada Minu...  v3RtLIoptm8
# 3   Como sair do ZERO em Gráficos no Python [Seaborn]  -hlzk4FXlUU
# 4   Como sair do ZERO em Gráficos no Python [Matpl...  FDU-D8ddTU4
# 5   Como Integrar Python e SQL - Passo a Passo com...  Mdg1D-Kdmrw
# 6      Como Usar Pandas no PyCharm [Pandas no Python]  2_ytBPzqzJ4
# 7   Webscraping de 1000 Páginas Automaticamente no...  kM9eyM7a9L8
# 8   Como Ler Textos Dentro de Imagens com Python [...  Wx3SyNwZtsA
# 9           Como Trabalhar com Arquivos CSV no Python  AnJPtKLtc7o
# 10  Como Tratar Valores Vazios em uma Base de Dado...  rVJW-rgJUkY
# 11  Interface Gráfica + Banco (SQlite) + Exportaçã...  9z4Uz9Y-TZM
# 12  Trade de Criptomoedas com Python - API da Binance  NxZ_cl8MUEU
# 13  Reconhecimento Facial com Python, OpenCV e Med...  mCcPmlr7y3U
# 14  Break e Continue no Python - Ferramentas da Es...  BMQ3lM-GVu8
# 15  Saindo do Zero com Split no Python - Separação...  DjNCk0Dgnkc
# 16  Case Prático de Análise de Dados no Python par...  vgPPr9dFOZQ
# 17  Case de Compras em Python - Avaliação de Propo...  T5X1wWiBPaE
# 18  Case Prático em Python - Cobranças Automáticas...  dUxpMU9Bw3U
# 19  Como Mentir com Gráficos - Analisando Gráficos...  BVyZmccKDcQ
# 20  Como Salvar Tweets em um Banco de Dados com Py...  xfv29MiZ4BU
# 21  É Possível Prever o Resultado da Mega Sena com...  CRIjrfuaey8
# 22                                      Private video  MvjdqHHsnJ8
# 23     Criando Dashboards em Python com Dash e Plotly  aS64PvDqCbU
# 24                   CRUD em Python  - Python e MySQL  _q3j25ACmQ4
# 25  Firebase e Python - Introdução a REST API do F...  QkDiBWJ8Row
# 26  Estatística para Data Science no Python - Por ...  lm5MK7SAbs0
# 27  Contas em Python Não Estão Certas? Números com...  CH37p_qPwIw
# 28     Análise Exploratória IMPRESSIONADORA em Python  4sxhE3wP3Ug
# 29  Usando Machine Learning para Estimativa de Ven...  3qym7vqFybs
#
#                                     video_description        published_date  \
# 0   Quer saber mais sobre o nosso Curso Completo d...  2021-07-09T21:19:48Z
# 1   Quer saber mais sobre o nosso Curso Completo d...  2021-07-19T17:11:06Z
# 2   Quer saber mais sobre o nosso Curso Completo d...  2021-07-22T12:02:26Z
# 3   Quer saber mais sobre o nosso Curso Completo d...  2021-07-26T17:53:30Z
# 4   Quer saber mais sobre o nosso Curso Completo d...  2021-07-26T17:54:41Z
# 5   Quer saber mais sobre o nosso Curso Completo d...  2021-08-26T19:19:35Z
# 6   Quer saber mais sobre o nosso Curso Completo d...  2021-09-13T16:27:44Z
# 7   Quer saber mais sobre o nosso Curso Completo d...  2021-09-20T14:27:42Z
# 8   Quer saber mais sobre o nosso Curso Completo d...  2021-09-24T15:06:17Z
# 9   Quer saber mais sobre o nosso Curso Completo d...  2021-10-28T19:54:37Z
# 10  Quer saber mais sobre o nosso Curso Completo d...  2021-11-11T13:42:44Z
# 11  Quer saber mais sobre o nosso Curso Completo d...  2021-11-29T20:24:43Z
# 12  Quer saber mais sobre o nosso Curso Completo d...  2021-12-02T13:55:01Z
# 13  Quer saber mais sobre o nosso Curso Completo d...  2021-12-09T11:00:14Z
# 14  Quer saber mais sobre o nosso Curso Completo d...  2021-12-10T17:41:04Z
# 15  Quer saber mais sobre o nosso Curso Completo d...  2021-12-27T12:09:34Z
# 16  Quer saber mais sobre o nosso Curso Completo d...  2022-01-03T11:55:33Z
# 17  Quer saber mais sobre o nosso Curso Completo d...  2022-01-17T18:18:56Z
# 18  Quer saber mais sobre o nosso Curso Completo d...  2022-01-24T18:59:35Z
# 19  Quer saber mais sobre o nosso Curso Completo d...  2022-02-14T11:30:23Z
# 20  Quer saber mais sobre o nosso Curso Completo d...  2022-02-21T19:33:23Z
# 21  Quer saber mais sobre o nosso Curso Completo d...  2022-02-24T13:07:02Z
# 22                             This video is private.  2022-03-03T13:09:17Z
# 23  Quer saber mais sobre o nosso Curso Completo d...  2022-03-03T16:22:09Z
# 24  Quer saber mais sobre o nosso Curso Completo d...  2022-03-11T18:19:18Z
# 25  Quer saber mais sobre o nosso Curso Completo d...  2022-03-19T01:27:31Z
# 26  Quer saber mais sobre o nosso Curso Completo d...  2022-03-21T11:43:37Z
# 27  Quer saber mais sobre o nosso Curso Completo d...  2022-03-25T18:15:25Z
# 28  Quer saber mais sobre o nosso Curso Completo d...  2022-03-28T00:11:28Z
# 29  Quer saber mais sobre o nosso Curso Completo d...  2022-04-11T13:33:52Z
#
#                extraction_date likes  views comment  \
# 0   2022-04-14 11:16:05.045146  3686  54607      71
# 1   2022-04-14 11:16:05.045146   687   6858      26
# 2   2022-04-14 11:16:05.045146   743   9479      26
# 3   2022-04-14 11:16:05.045146   393   5443      19
# 4   2022-04-14 11:16:05.045146   761   9402      31
# 5   2022-04-14 11:16:05.045146  3190  36121     218
# 6   2022-04-14 11:16:05.045146   446   7965      18
# 7   2022-04-14 11:16:05.045146   480   8587      28
# 8   2022-04-14 11:16:05.045146   863  12141      49
# 9   2022-04-14 11:16:05.045146   465   8147      17
# 10  2022-04-14 11:16:05.045146   295   3262      22
# 11  2022-04-14 11:16:05.045146   749  10646      29
# 12  2022-04-14 11:16:05.045146  1482  25714      66
# 13  2022-04-14 11:16:05.045146   992  11816      30
# 14  2022-04-14 11:16:05.045146   369   3704      20
# 15  2022-04-14 11:16:05.045146   295   3241      14
# 16  2022-04-14 11:16:05.045146  1000  12561      63
# 17  2022-04-14 11:16:05.045146   331   4516      28
# 18  2022-04-14 11:16:05.045146   513   7555      28
# 19  2022-04-14 11:16:05.045146   258   3000      14
# 20  2022-04-14 11:16:05.045146   216   2584      11
# 21  2022-04-14 11:16:05.045146   468   4443      37
# 22  2022-04-14 11:16:05.045146  1031  15369      33
# 23  2022-04-14 11:16:05.045146   800   9609      45
# 24  2022-04-14 11:16:05.045146   475   4834      21
# 25  2022-04-14 11:16:05.045146   423   4827      16
# 26  2022-04-14 11:16:05.045146   369   3529      10
# 27  2022-04-14 11:16:05.045146   474   5401      20
# 28  2022-04-14 11:16:05.045146   269   2874       7
# 29  2022-04-14 11:16:05.045146  None   None    None
#
#                                             thumbnail
# 0   {'default': {'url': 'https://i.ytimg.com/vi/kC...
# 1   {'default': {'url': 'https://i.ytimg.com/vi/eb...
# 2   {'default': {'url': 'https://i.ytimg.com/vi/v3...
# 3   {'default': {'url': 'https://i.ytimg.com/vi/-h...
# 4   {'default': {'url': 'https://i.ytimg.com/vi/FD...
# 5   {'default': {'url': 'https://i.ytimg.com/vi/Md...
# 6   {'default': {'url': 'https://i.ytimg.com/vi/2_...
# 7   {'default': {'url': 'https://i.ytimg.com/vi/kM...
# 8   {'default': {'url': 'https://i.ytimg.com/vi/Wx...
# 9   {'default': {'url': 'https://i.ytimg.com/vi/An...
# 10  {'default': {'url': 'https://i.ytimg.com/vi/rV...
# 11  {'default': {'url': 'https://i.ytimg.com/vi/9z...
# 12  {'default': {'url': 'https://i.ytimg.com/vi/Nx...
# 13  {'default': {'url': 'https://i.ytimg.com/vi/mC...
# 14  {'default': {'url': 'https://i.ytimg.com/vi/BM...
# 15  {'default': {'url': 'https://i.ytimg.com/vi/Dj...
# 16  {'default': {'url': 'https://i.ytimg.com/vi/vg...
# 17  {'default': {'url': 'https://i.ytimg.com/vi/T5...
# 18  {'default': {'url': 'https://i.ytimg.com/vi/dU...
# 19  {'default': {'url': 'https://i.ytimg.com/vi/BV...
# 20  {'default': {'url': 'https://i.ytimg.com/vi/xf...
# 21  {'default': {'url': 'https://i.ytimg.com/vi/CR...
# 22                                                 {}
# 23  {'default': {'url': 'https://i.ytimg.com/vi/aS...
# 24  {'default': {'url': 'https://i.ytimg.com/vi/_q...
# 25  {'default': {'url': 'https://i.ytimg.com/vi/Qk...
# 26  {'default': {'url': 'https://i.ytimg.com/vi/lm...
# 27  {'default': {'url': 'https://i.ytimg.com/vi/CH...
# 28  {'default': {'url': 'https://i.ytimg.com/vi/4s...
# 29  {'default': {'url': 'https://i.ytimg.com/vi/3q...
